# %%
import os
import pandas as pd

# %%
#C:\Users\User\Documents\Atividades_andamento\Nayana

# %%
print(os.getcwd())
path_dir = r"C:\Users\User\Documents\Atividades_andamento\Nayana"
os.chdir(path_dir)
print(os.getcwd())
# Out:
# c:\Users\User\Documents\Atividades_andamento\Nayana
# C:\Users\User\Documents\Atividades_andamento\Nayana

# %%
df = pd.read_excel('Fechamento_Tap_rev01.xlsx',skiprows=6, header=None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\compat\_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_excel('Fechamento_Tap_rev01.xlsx',skiprows=6, header=None)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:483, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     481 if not isinstance(io, ExcelFile):
#     482     should_close = True
# --> 483     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     484 elif engine and engine != io.engine:
#     485     raise ValueError(
#     486         "Engine should not be specified when passing "
#     487         "an ExcelFile - ExcelFile already has the engine set"
#     488     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:1672, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1669 self.engine = engine
#    1670 self.storage_options = storage_options
# -> 1672 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_openpyxl.py:548, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     533 @doc(storage_options=_shared_docs["storage_options"])
#     534 def __init__(
#     535     self,
#     536     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#     537     storage_options: StorageOptions = None,
#     538 ) -> None:
#     539     """
#     540     Reader using openpyxl engine.
#     541
#    (...)
#     546     {storage_options}
#     547     """
# --> 548     import_optional_dependency("openpyxl")
#     549     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\compat\_optional.py:145, in import_optional_dependency(name, extra, errors, min_version)
#     143 except ImportError:
#     144     if errors == "raise":
# --> 145         raise ImportError(msg)
#     146     else:
#     147         return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
df.head(10)
# Out:
#    0                     1                             2  3      4   5    6   \
# 0 NaN  Depósitos de estéril        Depósito de Estéril E1  X    144 NaN  200
# 1 NaN                   NaN        Depósito de Estéril E2  X     66 NaN   78
# 2 NaN                   NaN        Depósito de Estéril E3  X     60 NaN   70
# 3 NaN                   NaN  Depósito de Estéril E7/T5/E9  X    260 NaN  150
# 4 NaN                   NaN        Depósito de Estéril E8  X     95 NaN  220
# 5 NaN                   NaN        Depósito de Titânio T1  X     29 NaN   85
# 6 NaN                   NaN        Depósito de Titânio T2  X     42 NaN  110
# 7 NaN                   NaN        Depósito de Titânio T4  X    162 NaN  234
# 8 NaN                   NaN        Depósito de Estéril E4  X   35.3 NaN   80
# 9 NaN                   NaN        Depósito de Estéril E6  X  173.7 NaN  300
#
#     7    8    9   ... 65 66 67 68 69 70 71 72 73 74
# 0  NaN  NaN  NaN  ...  X  X  X  X  X  X  X  X  X  X
# 1  NaN  NaN  NaN  ...  X  X  X  X  X  X  X  X  X  X
# 2  NaN  NaN  NaN  ...  X  X  X  X  X  X  X  X  X  X
# 3  NaN  NaN  NaN  ...  X  X  X  X  X  X  X  X  X  X
# 4  NaN  NaN  NaN  ...  X  X  X  X  X  X  X  X  X  X
# 5  NaN  NaN  NaN  ...  X  X  X  X  X  X  X  X  X  X
# 6  NaN  NaN  NaN  ...  X  X  X  X  X  X  X  X  X  X
# 7  NaN  NaN  NaN  ...  X  X  X  X  X  X  X  X  X  X
# 8  NaN  NaN  NaN  ...  X  X  -  X  X  X  X  X  -  X
# 9  NaN  NaN  NaN  ...  X  X  -  X  X  X  X  X  -  X
#
# [10 rows x 75 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
nomes = list(df.iloc[:,2].values)

# %% [markdown]
# type(nomes)

# %%
nomes
# Out:
# ['Depósito de Estéril E1',
#  'Depósito de Estéril E2',
#  'Depósito de Estéril E3',
#  'Depósito de Estéril E7/T5/E9',
#  'Depósito de Estéril E8',
#  'Depósito de Titânio T1',
#  'Depósito de Titânio T2',
#  'Depósito de Titânio T4',
#  'Depósito de Estéril E4',
#  'Depósito de Estéril E6',
#  'Depósito de Titânio T6',
#  'Depósito de Estéril E11/Bigorna',
#  'Planta de Britagem',
#  'Planta de Beneficiamento',
#  'Estação de bombeamento Mineroduto',
#  'Planta Piloto',
#  'Pátio de minério britado',
#  'Pátios de resíduos',
#  'Pátio de Ultrafinos',
#  'Pátio de Apoio',
#  'Barragem BR',
#  'Barragem BL1',
#  'Pilha de Magnetita',
#  'PDR-I',
#  'PDR-II',
#  'PDM',
#  'Barragem BD2',
#  'Barragem BD5',
#  'Barragem BA3',
#  'Infraestrutura da Mina',
#  'Galpões Geologia e Sondagem',
#  'Metal AR',
#  'Área de Britagem',
#  'Infraestrutura da Usina',
#  'Depósitos de Explosivos',
#  'ORICA',
#  'Áreas de Manutenção ',
#  'Áreas de armazenagem de peças e resíduos',
#  'Bombeamento Barragem',
#  'Reservatórios de água e ETA',
#  'Tratamento de Efluentes',
#  'Subestação CG71',
#  'Infraestrutura administrativa e escritórios',
#  'Acessos e estacionamentos',
#  'Barragem BRI',
#  'Ponds Barragem BD2',
#  'Pond Unidade de Beneficiamento',
#  'Mineroduto',
#  'Áreas desativadas e/ou removidas do Complexo',
#  'Áreas Verdes Protegidas',
#  'Áreas Verdes Não Protegidas',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
barragens =[]
rows =[]
cont = -1
cajati =['Barragem B1', 'Barragem B2', 'Barragem B12']
itapira =['Barragem BR', 'Barragem BL-1', 'Barragem BD-2', 'Barragem BD-5', 'Barragem BA-3']
itapira =['Barragem BR', 'Barragem BL1', 'Barragem BD2', 'Barragem BD5', 'Barragem BA3']
for word in nomes:
    cont += 1
    try:
        if word in itapira:
            barragens.append(word)
            rows.append(cont)
    except:
        pass
print(barragens)
print(rows)

# %%
df_filter = df.iloc[rows,:]
df_filter
# Out:
#     0                                     1             2  3    4   5   6   \
# 20 NaN  Estruturas de disposição de rejeitos   Barragem BR  X  720 NaN  81
# 21 NaN                                   NaN  Barragem BL1  X  668 NaN  94
# 26 NaN  Depósitos de contenção de sedimentos  Barragem BD2  X   30 NaN  21
# 27 NaN                                   NaN  Barragem BD5  X   80 NaN  33
# 28 NaN                                   NaN  Barragem BA3  X    8 NaN  17
#
#      7    8    9   ... 65 66 67 68 69 70 71 72 73 74
# 20  NaN  NaN  NaN  ...  X  X  -  X  X  X  X  X  -  X
# 21  NaN  NaN  NaN  ...  X  X  -  X  X  X  X  X  -  X
# 26  NaN  NaN  NaN  ...  X  X  -  X  X  X  X  X  -  X
# 27  NaN  NaN  NaN  ...  X  X  -  X  X  X  X  X  -  X
# 28  NaN  NaN  NaN  ...  -  -  -  X  X  X  X  -  -  X
#
# [5 rows x 75 columns]

# %%
df_filter.to_excel('tapira_filter.xlsx')

# %%
files_ = ['Fechamento_Tap_rev01.xlsx','Fechamento_Ara_rev01.xlsx',
         'Fechamento_Cat_rev01.xlsx','Fechamento_Pat_rev01.xlsx',
         'Fechamento_Caj_rev01.xlsx'
         ]
print(files_)

tapira =['Barragem BR', 'Barragem BL1', 'Barragem BD2', 'Barragem BD5', 'Barragem BA3']
araxa = ['Barragem B1/B4', 'Barragem B5', 'Barragem B2','Barragem B6']
catalao =['Barragem de Magnetita', 'Barragem de Rejeitos BR']
patrocinio = ['Barragem de Lamas', 'Barragem de Lamas (cenário 1)']
cajati = ['Barragem B1', 'Barragem B2', 'Barragem B12']
set_ = [tapira,araxa,catalao,patrocinio,cajati]
set_name = []
k = -1
for file_ in files_:
  df = pd.read_excel(file_,skiprows=6, header=None)
  k += 1
  nomes = list(df.iloc[:,2].values)
  print(nomes)
  cont = -1
  barragens =[]
  rows =[]
  id_row = []
  id_k = 0
  for word in nomes:
    cont += 1
    try:
        if word in set_[k]:
          id_k += 1
          barragens.append(word)
          rows.append(cont)
          id_row.append(set_name[k]+str(id_k))
    except:
        pass
  print(barragens)
  print(rows)
  print(id_row)
