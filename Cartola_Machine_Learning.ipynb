# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Doubts_Students/blob/master/Cartola_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Neural Networks for Regression problems

# %% [markdown]
# Neural networks are well known for classification problems, for example, they are used in handwritten digits classification, but the question is will it be fruitful if we used them for regression problems?
#
# In this article I will use a deep neural network to predict house pricing using a dataset from Kaggle .
#
# You can download the dataset from [Here](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data)

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/2000/1*vUKwarc7rCouMzSt0Ksakw.jpeg)

# %% [markdown]
# ## Contents :
#     1- Process the dataset
#     2- Make the deep neural network
#     3- Train the DNN
#     4- Test the DNN
#     5- Compare the result from the DNN to another ML algorithm

# %% [markdown]
# **First of all, we will import the needed dependencies :**

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## First : Processing the dataset
# We will not go deep in processing the dataset, all we want to do is getting the dataset ready to be fed into our models .
#
# We will get rid of any features with missing values, then we will encode the categorical features, that's it.

# %% [markdown]
# ### Load the dataset :
# * Load train and test data into pandas DataFrames
# * Combine train and test data to process them together

# %%
def get_data():
    #get train data
    train_data_path ='train.csv'
    train = pd.read_csv(train_data_path)
    
    #get test data
    test_data_path ='test.csv'
    test = pd.read_csv(test_data_path)
    
    return train , test

def get_combined_data():
  #reading train data
  train , test = get_data()

  target = train.Pontosx
  train.drop(['Pontosx'],axis = 1 , inplace = True)

  combined = train.append(test)
  combined.reset_index(inplace=True)
  combined.drop(['index', 'Id'], inplace=True, axis=1)
  return combined, target

#Load train and test data into pandas DataFrames
train_data, test_data = get_data()

#Combine train and test data to process them together
combined, target = get_combined_data()

# %%
combined.describe()
# Out:
#           Rodada x     Preco_x-1  PrecoVariacao_x-1     Ano       Casa x  \
# count  7538.000000   7538.000000        7538.000000  7538.0  7538.000000
# mean     24.140621   6966.240382          13.434598  2018.0     0.504378
# std       8.355817   3869.317298         973.547245     0.0     0.500014
# min      10.000000    730.000000       -4730.000000  2018.0     0.000000
# 25%      17.000000   4030.000000        -540.000000  2018.0     0.000000
# 50%      24.000000   6200.000000           0.000000  2018.0     1.000000
# 75%      31.000000   9220.000000         530.000000  2018.0     1.000000
# max      38.000000  23340.000000        6200.000000  2018.0     1.000000
#
#        PontosMedia_x-1    lose_odds    draw_odds   FS_med_x-1   PE_med_x-1  \
# count      7538.000000  7538.000000  7538.000000  7538.000000  7538.000000
# mean       3085.555850   380.535553   293.316662  1043.376492  1751.366145
# std        1971.544073   181.795183    41.475776   758.404904  1002.508518
# min       -6600.000000    49.000000   138.000000     0.000000     0.000000
# 25%        1800.000000   236.000000   268.000000   500.000000  1000.000000
# 50%        2920.000000   364.000000   306.000000  1000.000000  1692.000000
# 75%        4230.000000   508.000000   325.000000  1455.000000  2364.000000
# max       12830.000000   870.000000   357.000000  8000.000000  8000.000000
#
#        ...   PP_l05_x-1   RB_l05_x-1   FC_l05_x-1   GC_l05_x-1   CA_l05_x-1  \
# count  ...  7538.000000  7538.000000  7538.000000  7538.000000  7538.000000
# mean   ...     2.286150  1158.583311  1122.274874     2.498408   173.347705
# std    ...    21.722592   955.686468   791.872804    22.420933   195.311964
# min    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    ...     0.000000   400.000000   600.000000     0.000000     0.000000
# 50%    ...     0.000000  1000.000000  1000.000000     0.000000   200.000000
# 75%    ...     0.000000  1750.000000  1600.000000     0.000000   200.000000
# max    ...   400.000000  6000.000000  6000.000000   333.000000  1000.000000
#
#         CV_l05_x-1   SG_l05_x-1   DD_l05_x-1   DP_l05_x-1   GS_l05_x-1
# count  7538.000000  7538.000000  7538.000000  7538.000000  7538.000000
# mean      8.936588   139.719687   100.457681     1.656010    80.078801
# std      46.568756   234.414398   388.260391    21.496108   320.179808
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000   200.000000     0.000000     0.000000     0.000000
# max    1000.000000  1000.000000  3500.000000  1000.000000  3000.000000
#
# [8 rows x 44 columns]

# %% [markdown]
# let's define a function to get the columns that don't have any missing values

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %% [markdown]
# Get the columns that do not have any missing values .

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

# %% [markdown]
# Let's see how many columns we got

# %%
print ('Number of numerical columns with no nan values :',len(num_cols))
print ('Number of nun-numerical columns with no nan values :',len(cat_cols))
# Out:
# Number of numerical columns with no nan values : 44
# Number of nun-numerical columns with no nan values : 4

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %% [markdown]
# **The correlation between the features**

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %% [markdown]
# From the correlation heatmap above, we see that about 15 features are highly correlated with the target.

# %% [markdown]
# **One Hot Encode The Categorical Features :**
#
# We will encode the categorical features using one hot encoding.

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df

# %%
print('There were {} columns before encoding categorical features'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
# Out:
# There were 48 columns before encoding categorical features
# There are 667 columns after encoding categorical features

# %% [markdown]
# Now, split back combined dataFrame to training data and test data

# %%
def split_combined():
    global combined
    train = combined[:39017]
    test = combined[39017:]

    return train , test

# %%
train, test = split_combined()

# %% [markdown]
# ## Second : Make the Deep Neural Network
#  * Define a sequential model
#  * Add some dense layers
#  * Use '**relu**' as the activation function in the hidden layers
#  * Use a '**normal**' initializer as the kernal_intializer
#            Initializers define the way to set the initial random weights of Keras layers.
#  * We will use mean_absolute_error as a loss function
#  * Define the output layer with only one node
#  * Use 'linear 'as the activation function for the output layer

# %%
NN_model = Sequential()

# %% [markdown]
# **The Input Layer**

# %%
NN_model.add(Dense(48, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# **The Hidden Layers**

# %%
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
#NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
#NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# %% [markdown]
# **The Output Layer**

# %%
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# %% [markdown]
# **Compile the network**

# %%
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 48)                32064
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               12544
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 44,865
# Trainable params: 44,865
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Define a checkpoint callback :**

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %% [markdown]
# ## Third : Train the model :

# %%
NN_model.fit(train, target, epochs=50000, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 4824 samples, validate on 1206 samples
# Epoch 1/50000
# 4824/4824 [==============================] - 2s 340us/step - loss: 3205.6461 - mean_absolute_error: 3205.6461 - val_loss: 3019.3259 - val_mean_absolute_error: 3019.3259
#
# Epoch 00001: val_loss improved from inf to 3019.32588, saving model to Weights-001--3019.32588.hdf5
# Epoch 2/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 3147.4496 - mean_absolute_error: 3147.4496 - val_loss: 2992.4452 - val_mean_absolute_error: 2992.4452
#
# Epoch 00002: val_loss improved from 3019.32588 to 2992.44520, saving model to Weights-002--2992.44520.hdf5
# Epoch 3/50000
# 4824/4824 [==============================] - 1s 112us/step - loss: 3146.5416 - mean_absolute_error: 3146.5416 - val_loss: 2995.8618 - val_mean_absolute_error: 2995.8618
#
# Epoch 00003: val_loss did not improve from 2992.44520
# Epoch 4/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 3129.6166 - mean_absolute_error: 3129.6166 - val_loss: 3009.1058 - val_mean_absolute_error: 3009.1058
#
# Epoch 00004: val_loss did not improve from 2992.44520
# Epoch 5/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 3113.1156 - mean_absolute_error: 3113.1156 - val_loss: 3007.5980 - val_mean_absolute_error: 3007.5980
#
# Epoch 00005: val_loss did not improve from 2992.44520
# Epoch 6/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 3109.5190 - mean_absolute_error: 3109.5190 - val_loss: 2974.6125 - val_mean_absolute_error: 2974.6125
#
# Epoch 00006: val_loss improved from 2992.44520 to 2974.61245, saving model to Weights-006--2974.61245.hdf5
# Epoch 7/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 3097.2666 - mean_absolute_error: 3097.2666 - val_loss: 3000.4790 - val_mean_absolute_error: 3000.4790
#
# Epoch 00007: val_loss did not improve from 2974.61245
# Epoch 8/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 3091.3760 - mean_absolute_error: 3091.3760 - val_loss: 2963.8038 - val_mean_absolute_error: 2963.8038
#
# Epoch 00008: val_loss improved from 2974.61245 to 2963.80376, saving model to Weights-008--2963.80376.hdf5
# Epoch 9/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 3087.0057 - mean_absolute_error: 3087.0057 - val_loss: 2961.4216 - val_mean_absolute_error: 2961.4216
#
# Epoch 00009: val_loss improved from 2963.80376 to 2961.42160, saving model to Weights-009--2961.42160.hdf5
# Epoch 10/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 3087.4119 - mean_absolute_error: 3087.4119 - val_loss: 2955.4309 - val_mean_absolute_error: 2955.4309
#
# Epoch 00010: val_loss improved from 2961.42160 to 2955.43089, saving model to Weights-010--2955.43089.hdf5
# Epoch 11/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 3077.8412 - mean_absolute_error: 3077.8412 - val_loss: 3025.3482 - val_mean_absolute_error: 3025.3482
#
# Epoch 00011: val_loss did not improve from 2955.43089
# Epoch 12/50000
# 4824/4824 [==============================] - 1s 113us/step - loss: 3074.8594 - mean_absolute_error: 3074.8594 - val_loss: 2961.5789 - val_mean_absolute_error: 2961.5789
#
# Epoch 00012: val_loss did not improve from 2955.43089
# Epoch 13/50000
# 4824/4824 [==============================] - 1s 112us/step - loss: 3067.3863 - mean_absolute_error: 3067.3863 - val_loss: 2965.0872 - val_mean_absolute_error: 2965.0872
#
# Epoch 00013: val_loss did not improve from 2955.43089
# Epoch 14/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 3072.0655 - mean_absolute_error: 3072.0655 - val_loss: 2963.2035 - val_mean_absolute_error: 2963.2035
#
# Epoch 00014: val_loss did not improve from 2955.43089
# Epoch 15/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 3068.0953 - mean_absolute_error: 3068.0953 - val_loss: 2950.8468 - val_mean_absolute_error: 2950.8468
#
# Epoch 00015: val_loss improved from 2955.43089 to 2950.84678, saving model to Weights-015--2950.84678.hdf5
# Epoch 16/50000
# 4824/4824 [==============================] - 1s 106us/step - loss: 3052.9886 - mean_absolute_error: 3052.9886 - val_loss: 2981.1354 - val_mean_absolute_error: 2981.1354
#
# Epoch 00016: val_loss did not improve from 2950.84678
# Epoch 17/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 3045.5011 - mean_absolute_error: 3045.5011 - val_loss: 2966.1920 - val_mean_absolute_error: 2966.1920
#
# Epoch 00017: val_loss did not improve from 2950.84678
# Epoch 18/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 3043.0573 - mean_absolute_error: 3043.0573 - val_loss: 3020.3775 - val_mean_absolute_error: 3020.3775
#
# Epoch 00018: val_loss did not improve from 2950.84678
# Epoch 19/50000
# 4824/4824 [==============================] - 1s 112us/step - loss: 3035.6492 - mean_absolute_error: 3035.6492 - val_loss: 3017.9209 - val_mean_absolute_error: 3017.9209
#
# Epoch 00019: val_loss did not improve from 2950.84678
# Epoch 20/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 3031.9876 - mean_absolute_error: 3031.9876 - val_loss: 2966.2962 - val_mean_absolute_error: 2966.2962
#
# Epoch 00020: val_loss did not improve from 2950.84678
# Epoch 21/50000
# 4824/4824 [==============================] - 1s 112us/step - loss: 3025.1123 - mean_absolute_error: 3025.1123 - val_loss: 2965.5468 - val_mean_absolute_error: 2965.5468
#
# Epoch 00021: val_loss did not improve from 2950.84678
# Epoch 22/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 3030.2692 - mean_absolute_error: 3030.2692 - val_loss: 2984.8982 - val_mean_absolute_error: 2984.8982
#
# Epoch 00022: val_loss did not improve from 2950.84678
# Epoch 23/50000
# 4824/4824 [==============================] - 1s 116us/step - loss: 3020.3343 - mean_absolute_error: 3020.3343 - val_loss: 3013.9508 - val_mean_absolute_error: 3013.9508
#
# Epoch 00023: val_loss did not improve from 2950.84678
# Epoch 24/50000
# 4824/4824 [==============================] - 1s 114us/step - loss: 3024.1638 - mean_absolute_error: 3024.1638 - val_loss: 2968.5633 - val_mean_absolute_error: 2968.5633
#
# Epoch 00024: val_loss did not improve from 2950.84678
# Epoch 25/50000
# 4824/4824 [==============================] - 1s 116us/step - loss: 3012.4692 - mean_absolute_error: 3012.4692 - val_loss: 2969.5121 - val_mean_absolute_error: 2969.5121
#
# Epoch 00025: val_loss did not improve from 2950.84678
# Epoch 26/50000
# 4824/4824 [==============================] - 1s 119us/step - loss: 3007.5942 - mean_absolute_error: 3007.5942 - val_loss: 2976.7116 - val_mean_absolute_error: 2976.7116
#
# Epoch 00026: val_loss did not improve from 2950.84678
# Epoch 27/50000
# 4824/4824 [==============================] - 1s 113us/step - loss: 2998.5718 - mean_absolute_error: 2998.5718 - val_loss: 2984.3541 - val_mean_absolute_error: 2984.3541
#
# Epoch 00027: val_loss did not improve from 2950.84678
# Epoch 28/50000
# 4824/4824 [==============================] - 1s 116us/step - loss: 2998.7769 - mean_absolute_error: 2998.7769 - val_loss: 2980.6976 - val_mean_absolute_error: 2980.6976
#
# Epoch 00028: val_loss did not improve from 2950.84678
# Epoch 29/50000
# 4824/4824 [==============================] - 1s 112us/step - loss: 2999.9908 - mean_absolute_error: 2999.9908 - val_loss: 2986.7889 - val_mean_absolute_error: 2986.7889
#
# Epoch 00029: val_loss did not improve from 2950.84678
# Epoch 30/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2993.1506 - mean_absolute_error: 2993.1506 - val_loss: 2992.8099 - val_mean_absolute_error: 2992.8099
#
# Epoch 00030: val_loss did not improve from 2950.84678
# Epoch 31/50000
# 4824/4824 [==============================] - 1s 118us/step - loss: 2983.6142 - mean_absolute_error: 2983.6142 - val_loss: 3034.3723 - val_mean_absolute_error: 3034.3723
#
# Epoch 00031: val_loss did not improve from 2950.84678
# Epoch 32/50000
# 4824/4824 [==============================] - 1s 117us/step - loss: 2977.9642 - mean_absolute_error: 2977.9642 - val_loss: 2997.9099 - val_mean_absolute_error: 2997.9099
#
# Epoch 00032: val_loss did not improve from 2950.84678
# Epoch 33/50000
# 4824/4824 [==============================] - 1s 113us/step - loss: 2973.3674 - mean_absolute_error: 2973.3674 - val_loss: 2996.5678 - val_mean_absolute_error: 2996.5678
#
# Epoch 00033: val_loss did not improve from 2950.84678
# Epoch 34/50000
# 4824/4824 [==============================] - 1s 117us/step - loss: 2962.0830 - mean_absolute_error: 2962.0830 - val_loss: 3024.5447 - val_mean_absolute_error: 3024.5447
#
# Epoch 00034: val_loss did not improve from 2950.84678
# Epoch 35/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2958.4193 - mean_absolute_error: 2958.4193 - val_loss: 3036.6196 - val_mean_absolute_error: 3036.6196
#
# Epoch 00035: val_loss did not improve from 2950.84678
# Epoch 36/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2959.1387 - mean_absolute_error: 2959.1387 - val_loss: 3004.2315 - val_mean_absolute_error: 3004.2315
#
# Epoch 00036: val_loss did not improve from 2950.84678
# Epoch 37/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2941.0505 - mean_absolute_error: 2941.0505 - val_loss: 3062.9340 - val_mean_absolute_error: 3062.9340
#
# Epoch 00037: val_loss did not improve from 2950.84678
# Epoch 38/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2950.8605 - mean_absolute_error: 2950.8605 - val_loss: 3005.7375 - val_mean_absolute_error: 3005.7375
#
# Epoch 00038: val_loss did not improve from 2950.84678
# Epoch 39/50000
# 4824/4824 [==============================] - 1s 116us/step - loss: 2953.0512 - mean_absolute_error: 2953.0512 - val_loss: 3094.3354 - val_mean_absolute_error: 3094.3354
#
# Epoch 00039: val_loss did not improve from 2950.84678
# Epoch 40/50000
# 4824/4824 [==============================] - 1s 112us/step - loss: 2941.2827 - mean_absolute_error: 2941.2827 - val_loss: 3013.2099 - val_mean_absolute_error: 3013.2099
#
# Epoch 00040: val_loss did not improve from 2950.84678
# Epoch 41/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2926.6699 - mean_absolute_error: 2926.6699 - val_loss: 3012.1921 - val_mean_absolute_error: 3012.1921
#
# Epoch 00041: val_loss did not improve from 2950.84678
# Epoch 42/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2914.9767 - mean_absolute_error: 2914.9767 - val_loss: 3011.0655 - val_mean_absolute_error: 3011.0655
#
# Epoch 00042: val_loss did not improve from 2950.84678
# Epoch 43/50000
# 4824/4824 [==============================] - 1s 113us/step - loss: 2907.6601 - mean_absolute_error: 2907.6601 - val_loss: 3033.1749 - val_mean_absolute_error: 3033.1749
#
# Epoch 00043: val_loss did not improve from 2950.84678
# Epoch 44/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2910.3992 - mean_absolute_error: 2910.3992 - val_loss: 3049.0209 - val_mean_absolute_error: 3049.0209
#
# Epoch 00044: val_loss did not improve from 2950.84678
# Epoch 45/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2896.2092 - mean_absolute_error: 2896.2092 - val_loss: 3074.9084 - val_mean_absolute_error: 3074.9084
#
# Epoch 00045: val_loss did not improve from 2950.84678
# Epoch 46/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2895.2104 - mean_absolute_error: 2895.2104 - val_loss: 3097.4143 - val_mean_absolute_error: 3097.4143
#
# Epoch 00046: val_loss did not improve from 2950.84678
# Epoch 47/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2896.7890 - mean_absolute_error: 2896.7890 - val_loss: 3063.6428 - val_mean_absolute_error: 3063.6428
#
# Epoch 00047: val_loss did not improve from 2950.84678
# Epoch 48/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2872.2977 - mean_absolute_error: 2872.2977 - val_loss: 3057.5810 - val_mean_absolute_error: 3057.5810
#
# Epoch 00048: val_loss did not improve from 2950.84678
# Epoch 49/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2870.7098 - mean_absolute_error: 2870.7098 - val_loss: 3081.7477 - val_mean_absolute_error: 3081.7477
#
# Epoch 00049: val_loss did not improve from 2950.84678
# Epoch 50/50000
# 4824/4824 [==============================] - 1s 106us/step - loss: 2867.3957 - mean_absolute_error: 2867.3957 - val_loss: 3063.2918 - val_mean_absolute_error: 3063.2918
#
# Epoch 00050: val_loss did not improve from 2950.84678
# Epoch 51/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2854.9622 - mean_absolute_error: 2854.9622 - val_loss: 3089.8544 - val_mean_absolute_error: 3089.8544
#
# Epoch 00051: val_loss did not improve from 2950.84678
# Epoch 52/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2852.5919 - mean_absolute_error: 2852.5919 - val_loss: 3097.9402 - val_mean_absolute_error: 3097.9402
#
# Epoch 00052: val_loss did not improve from 2950.84678
# Epoch 53/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2858.3167 - mean_absolute_error: 2858.3167 - val_loss: 3056.0495 - val_mean_absolute_error: 3056.0495
#
# Epoch 00053: val_loss did not improve from 2950.84678
# Epoch 54/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2850.3612 - mean_absolute_error: 2850.3612 - val_loss: 3064.2760 - val_mean_absolute_error: 3064.2760
#
# Epoch 00054: val_loss did not improve from 2950.84678
# Epoch 55/50000
# 4824/4824 [==============================] - 1s 112us/step - loss: 2836.4666 - mean_absolute_error: 2836.4666 - val_loss: 3069.3377 - val_mean_absolute_error: 3069.3377
#
# Epoch 00055: val_loss did not improve from 2950.84678
# Epoch 56/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2825.0018 - mean_absolute_error: 2825.0018 - val_loss: 3063.7952 - val_mean_absolute_error: 3063.7952
#
# Epoch 00056: val_loss did not improve from 2950.84678
# Epoch 57/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2818.5270 - mean_absolute_error: 2818.5270 - val_loss: 3087.8342 - val_mean_absolute_error: 3087.8342
#
# Epoch 00057: val_loss did not improve from 2950.84678
# Epoch 58/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2811.3511 - mean_absolute_error: 2811.3511 - val_loss: 3075.5036 - val_mean_absolute_error: 3075.5036
#
# Epoch 00058: val_loss did not improve from 2950.84678
# Epoch 59/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2812.9989 - mean_absolute_error: 2812.9989 - val_loss: 3132.3994 - val_mean_absolute_error: 3132.3994
#
# Epoch 00059: val_loss did not improve from 2950.84678
# Epoch 60/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2792.8558 - mean_absolute_error: 2792.8558 - val_loss: 3104.7393 - val_mean_absolute_error: 3104.7393
#
# Epoch 00060: val_loss did not improve from 2950.84678
# Epoch 61/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2800.3448 - mean_absolute_error: 2800.3448 - val_loss: 3090.9095 - val_mean_absolute_error: 3090.9095
#
# Epoch 00061: val_loss did not improve from 2950.84678
# Epoch 62/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2780.0188 - mean_absolute_error: 2780.0188 - val_loss: 3106.9248 - val_mean_absolute_error: 3106.9248
#
# Epoch 00062: val_loss did not improve from 2950.84678
# Epoch 63/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2784.8333 - mean_absolute_error: 2784.8333 - val_loss: 3111.0508 - val_mean_absolute_error: 3111.0508
#
# Epoch 00063: val_loss did not improve from 2950.84678
# Epoch 64/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2770.3065 - mean_absolute_error: 2770.3065 - val_loss: 3149.9188 - val_mean_absolute_error: 3149.9188
#
# Epoch 00064: val_loss did not improve from 2950.84678
# Epoch 65/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2752.5467 - mean_absolute_error: 2752.5467 - val_loss: 3135.4902 - val_mean_absolute_error: 3135.4902
#
# Epoch 00065: val_loss did not improve from 2950.84678
# Epoch 66/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2766.3116 - mean_absolute_error: 2766.3116 - val_loss: 3096.3909 - val_mean_absolute_error: 3096.3909
#
# Epoch 00066: val_loss did not improve from 2950.84678
# Epoch 67/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2744.0294 - mean_absolute_error: 2744.0294 - val_loss: 3076.0142 - val_mean_absolute_error: 3076.0142
#
# Epoch 00067: val_loss did not improve from 2950.84678
# Epoch 68/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2737.0511 - mean_absolute_error: 2737.0511 - val_loss: 3137.1501 - val_mean_absolute_error: 3137.1501
#
# Epoch 00068: val_loss did not improve from 2950.84678
# Epoch 69/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2737.9757 - mean_absolute_error: 2737.9757 - val_loss: 3111.7359 - val_mean_absolute_error: 3111.7359
#
# Epoch 00069: val_loss did not improve from 2950.84678
# Epoch 70/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2742.9705 - mean_absolute_error: 2742.9705 - val_loss: 3186.6193 - val_mean_absolute_error: 3186.6193
#
# Epoch 00070: val_loss did not improve from 2950.84678
# Epoch 71/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2730.1947 - mean_absolute_error: 2730.1947 - val_loss: 3133.6232 - val_mean_absolute_error: 3133.6232
#
# Epoch 00071: val_loss did not improve from 2950.84678
# Epoch 72/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2722.5027 - mean_absolute_error: 2722.5027 - val_loss: 3163.7327 - val_mean_absolute_error: 3163.7327
#
# Epoch 00072: val_loss did not improve from 2950.84678
# Epoch 73/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2720.5660 - mean_absolute_error: 2720.5660 - val_loss: 3182.9880 - val_mean_absolute_error: 3182.9880
#
# Epoch 00073: val_loss did not improve from 2950.84678
# Epoch 74/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2728.2398 - mean_absolute_error: 2728.2398 - val_loss: 3137.9264 - val_mean_absolute_error: 3137.9264
#
# Epoch 00074: val_loss did not improve from 2950.84678
# Epoch 75/50000
# 4824/4824 [==============================] - 1s 105us/step - loss: 2696.3945 - mean_absolute_error: 2696.3945 - val_loss: 3286.1115 - val_mean_absolute_error: 3286.1115
#
# Epoch 00075: val_loss did not improve from 2950.84678
# Epoch 76/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2699.9262 - mean_absolute_error: 2699.9262 - val_loss: 3125.0643 - val_mean_absolute_error: 3125.0643
#
# Epoch 00076: val_loss did not improve from 2950.84678
# Epoch 77/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2682.7643 - mean_absolute_error: 2682.7643 - val_loss: 3143.7961 - val_mean_absolute_error: 3143.7961
#
# Epoch 00077: val_loss did not improve from 2950.84678
# Epoch 78/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2675.6163 - mean_absolute_error: 2675.6163 - val_loss: 3153.7930 - val_mean_absolute_error: 3153.7930
#
# Epoch 00078: val_loss did not improve from 2950.84678
# Epoch 79/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2675.8149 - mean_absolute_error: 2675.8149 - val_loss: 3171.1342 - val_mean_absolute_error: 3171.1342
#
# Epoch 00079: val_loss did not improve from 2950.84678
# Epoch 80/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2671.3796 - mean_absolute_error: 2671.3796 - val_loss: 3199.4811 - val_mean_absolute_error: 3199.4811
#
# Epoch 00080: val_loss did not improve from 2950.84678
# Epoch 81/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2653.6153 - mean_absolute_error: 2653.6153 - val_loss: 3157.7830 - val_mean_absolute_error: 3157.7830
#
# Epoch 00081: val_loss did not improve from 2950.84678
# Epoch 82/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2648.4593 - mean_absolute_error: 2648.4593 - val_loss: 3187.8227 - val_mean_absolute_error: 3187.8227
#
# Epoch 00082: val_loss did not improve from 2950.84678
# Epoch 83/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2645.7039 - mean_absolute_error: 2645.7039 - val_loss: 3169.4119 - val_mean_absolute_error: 3169.4119
#
# Epoch 00083: val_loss did not improve from 2950.84678
# Epoch 84/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2633.5161 - mean_absolute_error: 2633.5161 - val_loss: 3225.6529 - val_mean_absolute_error: 3225.6529
#
# Epoch 00084: val_loss did not improve from 2950.84678
# Epoch 85/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2648.4510 - mean_absolute_error: 2648.4510 - val_loss: 3225.1256 - val_mean_absolute_error: 3225.1256
#
# Epoch 00085: val_loss did not improve from 2950.84678
# Epoch 86/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2627.6788 - mean_absolute_error: 2627.6788 - val_loss: 3181.8688 - val_mean_absolute_error: 3181.8688
#
# Epoch 00086: val_loss did not improve from 2950.84678
# Epoch 87/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2628.4341 - mean_absolute_error: 2628.4341 - val_loss: 3247.4370 - val_mean_absolute_error: 3247.4370
#
# Epoch 00087: val_loss did not improve from 2950.84678
# Epoch 88/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2614.7601 - mean_absolute_error: 2614.7601 - val_loss: 3192.1693 - val_mean_absolute_error: 3192.1693
#
# Epoch 00088: val_loss did not improve from 2950.84678
# Epoch 89/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2596.3271 - mean_absolute_error: 2596.3271 - val_loss: 3186.2899 - val_mean_absolute_error: 3186.2899
#
# Epoch 00089: val_loss did not improve from 2950.84678
# Epoch 90/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2605.8581 - mean_absolute_error: 2605.8581 - val_loss: 3197.7155 - val_mean_absolute_error: 3197.7155
#
# Epoch 00090: val_loss did not improve from 2950.84678
# Epoch 91/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2602.9407 - mean_absolute_error: 2602.9407 - val_loss: 3220.4306 - val_mean_absolute_error: 3220.4306
#
# Epoch 00091: val_loss did not improve from 2950.84678
# Epoch 92/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2581.1777 - mean_absolute_error: 2581.1777 - val_loss: 3199.1291 - val_mean_absolute_error: 3199.1291
#
# Epoch 00092: val_loss did not improve from 2950.84678
# Epoch 93/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2580.6040 - mean_absolute_error: 2580.6040 - val_loss: 3206.5936 - val_mean_absolute_error: 3206.5936
#
# Epoch 00093: val_loss did not improve from 2950.84678
# Epoch 94/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2568.9460 - mean_absolute_error: 2568.9460 - val_loss: 3220.2159 - val_mean_absolute_error: 3220.2159
#
# Epoch 00094: val_loss did not improve from 2950.84678
# Epoch 95/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2560.3864 - mean_absolute_error: 2560.3864 - val_loss: 3247.2583 - val_mean_absolute_error: 3247.2583
#
# Epoch 00095: val_loss did not improve from 2950.84678
# Epoch 96/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2564.5434 - mean_absolute_error: 2564.5434 - val_loss: 3214.2806 - val_mean_absolute_error: 3214.2806
#
# Epoch 00096: val_loss did not improve from 2950.84678
# Epoch 97/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2559.1756 - mean_absolute_error: 2559.1756 - val_loss: 3228.0814 - val_mean_absolute_error: 3228.0814
#
# Epoch 00097: val_loss did not improve from 2950.84678
# Epoch 98/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2552.9324 - mean_absolute_error: 2552.9324 - val_loss: 3195.3669 - val_mean_absolute_error: 3195.3669
#
# Epoch 00098: val_loss did not improve from 2950.84678
# Epoch 99/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2553.5375 - mean_absolute_error: 2553.5375 - val_loss: 3261.8692 - val_mean_absolute_error: 3261.8692
#
# Epoch 00099: val_loss did not improve from 2950.84678
# Epoch 100/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2528.7223 - mean_absolute_error: 2528.7223 - val_loss: 3214.7562 - val_mean_absolute_error: 3214.7562
#
# Epoch 00100: val_loss did not improve from 2950.84678
# Epoch 101/50000
# 4824/4824 [==============================] - 1s 113us/step - loss: 2537.8074 - mean_absolute_error: 2537.8074 - val_loss: 3254.9392 - val_mean_absolute_error: 3254.9392
#
# Epoch 00101: val_loss did not improve from 2950.84678
# Epoch 102/50000
# 4824/4824 [==============================] - 1s 112us/step - loss: 2526.3005 - mean_absolute_error: 2526.3005 - val_loss: 3273.0112 - val_mean_absolute_error: 3273.0112
#
# Epoch 00102: val_loss did not improve from 2950.84678
# Epoch 103/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2508.5882 - mean_absolute_error: 2508.5882 - val_loss: 3251.6859 - val_mean_absolute_error: 3251.6859
#
# Epoch 00103: val_loss did not improve from 2950.84678
# Epoch 104/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2518.5131 - mean_absolute_error: 2518.5131 - val_loss: 3255.9504 - val_mean_absolute_error: 3255.9504
#
# Epoch 00104: val_loss did not improve from 2950.84678
# Epoch 105/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2504.2115 - mean_absolute_error: 2504.2115 - val_loss: 3249.5653 - val_mean_absolute_error: 3249.5653
#
# Epoch 00105: val_loss did not improve from 2950.84678
# Epoch 106/50000
# 4824/4824 [==============================] - 1s 106us/step - loss: 2493.0455 - mean_absolute_error: 2493.0455 - val_loss: 3266.4915 - val_mean_absolute_error: 3266.4915
#
# Epoch 00106: val_loss did not improve from 2950.84678
# Epoch 107/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2497.4692 - mean_absolute_error: 2497.4692 - val_loss: 3250.8313 - val_mean_absolute_error: 3250.8313
#
# Epoch 00107: val_loss did not improve from 2950.84678
# Epoch 108/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2494.9054 - mean_absolute_error: 2494.9054 - val_loss: 3273.3515 - val_mean_absolute_error: 3273.3515
#
# Epoch 00108: val_loss did not improve from 2950.84678
# Epoch 109/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2483.5354 - mean_absolute_error: 2483.5354 - val_loss: 3279.8427 - val_mean_absolute_error: 3279.8427
#
# Epoch 00109: val_loss did not improve from 2950.84678
# Epoch 110/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2483.3991 - mean_absolute_error: 2483.3991 - val_loss: 3331.0911 - val_mean_absolute_error: 3331.0911
#
# Epoch 00110: val_loss did not improve from 2950.84678
# Epoch 111/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2469.7457 - mean_absolute_error: 2469.7457 - val_loss: 3268.4593 - val_mean_absolute_error: 3268.4593
#
# Epoch 00111: val_loss did not improve from 2950.84678
# Epoch 112/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2466.2525 - mean_absolute_error: 2466.2525 - val_loss: 3299.3587 - val_mean_absolute_error: 3299.3587
#
# Epoch 00112: val_loss did not improve from 2950.84678
# Epoch 113/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2457.5682 - mean_absolute_error: 2457.5682 - val_loss: 3292.2049 - val_mean_absolute_error: 3292.2049
#
# Epoch 00113: val_loss did not improve from 2950.84678
# Epoch 114/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2438.9262 - mean_absolute_error: 2438.9262 - val_loss: 3378.3271 - val_mean_absolute_error: 3378.3271
#
# Epoch 00114: val_loss did not improve from 2950.84678
# Epoch 115/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2439.4034 - mean_absolute_error: 2439.4034 - val_loss: 3251.2125 - val_mean_absolute_error: 3251.2125
#
# Epoch 00115: val_loss did not improve from 2950.84678
# Epoch 116/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2427.2843 - mean_absolute_error: 2427.2843 - val_loss: 3321.6158 - val_mean_absolute_error: 3321.6158
#
# Epoch 00116: val_loss did not improve from 2950.84678
# Epoch 117/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2429.1916 - mean_absolute_error: 2429.1916 - val_loss: 3298.8403 - val_mean_absolute_error: 3298.8403
#
# Epoch 00117: val_loss did not improve from 2950.84678
# Epoch 118/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2426.1009 - mean_absolute_error: 2426.1009 - val_loss: 3281.2990 - val_mean_absolute_error: 3281.2990
#
# Epoch 00118: val_loss did not improve from 2950.84678
# Epoch 119/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2416.9013 - mean_absolute_error: 2416.9013 - val_loss: 3317.1938 - val_mean_absolute_error: 3317.1938
#
# Epoch 00119: val_loss did not improve from 2950.84678
# Epoch 120/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2420.2845 - mean_absolute_error: 2420.2845 - val_loss: 3318.0974 - val_mean_absolute_error: 3318.0974
#
# Epoch 00120: val_loss did not improve from 2950.84678
# Epoch 121/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2434.8197 - mean_absolute_error: 2434.8197 - val_loss: 3340.4210 - val_mean_absolute_error: 3340.4210
#
# Epoch 00121: val_loss did not improve from 2950.84678
# Epoch 122/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2418.4841 - mean_absolute_error: 2418.4841 - val_loss: 3323.2957 - val_mean_absolute_error: 3323.2957
#
# Epoch 00122: val_loss did not improve from 2950.84678
# Epoch 123/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2424.5734 - mean_absolute_error: 2424.5734 - val_loss: 3261.8597 - val_mean_absolute_error: 3261.8597
#
# Epoch 00123: val_loss did not improve from 2950.84678
# Epoch 124/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2396.8389 - mean_absolute_error: 2396.8389 - val_loss: 3313.8716 - val_mean_absolute_error: 3313.8716
#
# Epoch 00124: val_loss did not improve from 2950.84678
# Epoch 125/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2391.1044 - mean_absolute_error: 2391.1044 - val_loss: 3329.4363 - val_mean_absolute_error: 3329.4363
#
# Epoch 00125: val_loss did not improve from 2950.84678
# Epoch 126/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2392.7323 - mean_absolute_error: 2392.7323 - val_loss: 3333.8271 - val_mean_absolute_error: 3333.8271
#
# Epoch 00126: val_loss did not improve from 2950.84678
# Epoch 127/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2379.6515 - mean_absolute_error: 2379.6515 - val_loss: 3306.5974 - val_mean_absolute_error: 3306.5974
#
# Epoch 00127: val_loss did not improve from 2950.84678
# Epoch 128/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2383.7330 - mean_absolute_error: 2383.7330 - val_loss: 3367.9117 - val_mean_absolute_error: 3367.9117
#
# Epoch 00128: val_loss did not improve from 2950.84678
# Epoch 129/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2385.5783 - mean_absolute_error: 2385.5783 - val_loss: 3359.4718 - val_mean_absolute_error: 3359.4718
#
# Epoch 00129: val_loss did not improve from 2950.84678
# Epoch 130/50000
# 4824/4824 [==============================] - 1s 112us/step - loss: 2354.4033 - mean_absolute_error: 2354.4033 - val_loss: 3317.6310 - val_mean_absolute_error: 3317.6310
#
# Epoch 00130: val_loss did not improve from 2950.84678
# Epoch 131/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2358.4145 - mean_absolute_error: 2358.4145 - val_loss: 3356.4315 - val_mean_absolute_error: 3356.4315
#
# Epoch 00131: val_loss did not improve from 2950.84678
# Epoch 132/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2345.5799 - mean_absolute_error: 2345.5799 - val_loss: 3391.6511 - val_mean_absolute_error: 3391.6511
#
# Epoch 00132: val_loss did not improve from 2950.84678
# Epoch 133/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2349.1435 - mean_absolute_error: 2349.1435 - val_loss: 3370.4971 - val_mean_absolute_error: 3370.4971
#
# Epoch 00133: val_loss did not improve from 2950.84678
# Epoch 134/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2343.7751 - mean_absolute_error: 2343.7751 - val_loss: 3410.6613 - val_mean_absolute_error: 3410.6613
#
# Epoch 00134: val_loss did not improve from 2950.84678
# Epoch 135/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2339.2180 - mean_absolute_error: 2339.2180 - val_loss: 3314.4315 - val_mean_absolute_error: 3314.4315
#
# Epoch 00135: val_loss did not improve from 2950.84678
# Epoch 136/50000
# 4824/4824 [==============================] - 1s 118us/step - loss: 2338.2196 - mean_absolute_error: 2338.2196 - val_loss: 3363.2177 - val_mean_absolute_error: 3363.2177
#
# Epoch 00136: val_loss did not improve from 2950.84678
# Epoch 137/50000
# 4824/4824 [==============================] - 1s 120us/step - loss: 2326.3018 - mean_absolute_error: 2326.3018 - val_loss: 3376.1405 - val_mean_absolute_error: 3376.1405
#
# Epoch 00137: val_loss did not improve from 2950.84678
# Epoch 138/50000
# 4824/4824 [==============================] - 1s 124us/step - loss: 2315.1626 - mean_absolute_error: 2315.1626 - val_loss: 3360.6888 - val_mean_absolute_error: 3360.6888
#
# Epoch 00138: val_loss did not improve from 2950.84678
# Epoch 139/50000
# 4824/4824 [==============================] - 1s 120us/step - loss: 2300.6456 - mean_absolute_error: 2300.6456 - val_loss: 3394.3894 - val_mean_absolute_error: 3394.3894
#
# Epoch 00139: val_loss did not improve from 2950.84678
# Epoch 140/50000
# 4824/4824 [==============================] - 1s 122us/step - loss: 2304.2904 - mean_absolute_error: 2304.2904 - val_loss: 3372.3435 - val_mean_absolute_error: 3372.3435
#
# Epoch 00140: val_loss did not improve from 2950.84678
# Epoch 141/50000
# 4824/4824 [==============================] - 1s 122us/step - loss: 2299.5447 - mean_absolute_error: 2299.5447 - val_loss: 3403.2707 - val_mean_absolute_error: 3403.2707
#
# Epoch 00141: val_loss did not improve from 2950.84678
# Epoch 142/50000
# 4824/4824 [==============================] - 1s 122us/step - loss: 2306.2228 - mean_absolute_error: 2306.2228 - val_loss: 3505.6588 - val_mean_absolute_error: 3505.6588
#
# Epoch 00142: val_loss did not improve from 2950.84678
# Epoch 143/50000
# 4824/4824 [==============================] - 1s 122us/step - loss: 2299.6878 - mean_absolute_error: 2299.6878 - val_loss: 3421.9682 - val_mean_absolute_error: 3421.9682
#
# Epoch 00143: val_loss did not improve from 2950.84678
# Epoch 144/50000
# 4824/4824 [==============================] - 1s 120us/step - loss: 2320.0023 - mean_absolute_error: 2320.0023 - val_loss: 3361.8151 - val_mean_absolute_error: 3361.8151
#
# Epoch 00144: val_loss did not improve from 2950.84678
# Epoch 145/50000
# 4824/4824 [==============================] - 1s 121us/step - loss: 2298.0843 - mean_absolute_error: 2298.0843 - val_loss: 3421.0148 - val_mean_absolute_error: 3421.0148
#
# Epoch 00145: val_loss did not improve from 2950.84678
# Epoch 146/50000
# 4824/4824 [==============================] - 1s 120us/step - loss: 2284.9780 - mean_absolute_error: 2284.9780 - val_loss: 3384.4667 - val_mean_absolute_error: 3384.4667
#
# Epoch 00146: val_loss did not improve from 2950.84678
# Epoch 147/50000
# 4824/4824 [==============================] - 1s 122us/step - loss: 2267.6149 - mean_absolute_error: 2267.6149 - val_loss: 3407.6650 - val_mean_absolute_error: 3407.6650
#
# Epoch 00147: val_loss did not improve from 2950.84678
# Epoch 148/50000
# 4824/4824 [==============================] - 1s 122us/step - loss: 2283.1681 - mean_absolute_error: 2283.1681 - val_loss: 3381.1443 - val_mean_absolute_error: 3381.1443
#
# Epoch 00148: val_loss did not improve from 2950.84678
# Epoch 149/50000
# 4824/4824 [==============================] - 1s 119us/step - loss: 2283.0142 - mean_absolute_error: 2283.0142 - val_loss: 3400.5266 - val_mean_absolute_error: 3400.5266
#
# Epoch 00149: val_loss did not improve from 2950.84678
# Epoch 150/50000
# 4824/4824 [==============================] - 1s 123us/step - loss: 2238.2058 - mean_absolute_error: 2238.2058 - val_loss: 3435.4620 - val_mean_absolute_error: 3435.4620
#
# Epoch 00150: val_loss did not improve from 2950.84678
# Epoch 151/50000
# 4824/4824 [==============================] - 1s 119us/step - loss: 2248.8852 - mean_absolute_error: 2248.8852 - val_loss: 3410.8844 - val_mean_absolute_error: 3410.8844
#
# Epoch 00151: val_loss did not improve from 2950.84678
# Epoch 152/50000
# 4824/4824 [==============================] - 1s 121us/step - loss: 2261.2301 - mean_absolute_error: 2261.2301 - val_loss: 3447.6273 - val_mean_absolute_error: 3447.6273
#
# Epoch 00152: val_loss did not improve from 2950.84678
# Epoch 153/50000
# 4824/4824 [==============================] - 1s 119us/step - loss: 2262.4673 - mean_absolute_error: 2262.4673 - val_loss: 3411.5791 - val_mean_absolute_error: 3411.5791
#
# Epoch 00153: val_loss did not improve from 2950.84678
# Epoch 154/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2259.8580 - mean_absolute_error: 2259.8580 - val_loss: 3399.5023 - val_mean_absolute_error: 3399.5023
#
# Epoch 00154: val_loss did not improve from 2950.84678
# Epoch 155/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2232.0409 - mean_absolute_error: 2232.0409 - val_loss: 3429.2071 - val_mean_absolute_error: 3429.2071
#
# Epoch 00155: val_loss did not improve from 2950.84678
# Epoch 156/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2229.1123 - mean_absolute_error: 2229.1123 - val_loss: 3409.3322 - val_mean_absolute_error: 3409.3322
#
# Epoch 00156: val_loss did not improve from 2950.84678
# Epoch 157/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2231.4443 - mean_absolute_error: 2231.4443 - val_loss: 3414.4285 - val_mean_absolute_error: 3414.4285
#
# Epoch 00157: val_loss did not improve from 2950.84678
# Epoch 158/50000
# 4824/4824 [==============================] - 1s 112us/step - loss: 2201.5163 - mean_absolute_error: 2201.5163 - val_loss: 3410.3163 - val_mean_absolute_error: 3410.3163
#
# Epoch 00158: val_loss did not improve from 2950.84678
# Epoch 159/50000
# 4824/4824 [==============================] - 1s 113us/step - loss: 2208.9730 - mean_absolute_error: 2208.9730 - val_loss: 3461.9675 - val_mean_absolute_error: 3461.9675
#
# Epoch 00159: val_loss did not improve from 2950.84678
# Epoch 160/50000
# 4824/4824 [==============================] - 1s 104us/step - loss: 2208.0970 - mean_absolute_error: 2208.0970 - val_loss: 3441.4264 - val_mean_absolute_error: 3441.4264
#
# Epoch 00160: val_loss did not improve from 2950.84678
# Epoch 161/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2216.1033 - mean_absolute_error: 2216.1033 - val_loss: 3441.0765 - val_mean_absolute_error: 3441.0765
#
# Epoch 00161: val_loss did not improve from 2950.84678
# Epoch 162/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2196.2248 - mean_absolute_error: 2196.2248 - val_loss: 3425.5059 - val_mean_absolute_error: 3425.5059
#
# Epoch 00162: val_loss did not improve from 2950.84678
# Epoch 163/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2206.0825 - mean_absolute_error: 2206.0825 - val_loss: 3421.9966 - val_mean_absolute_error: 3421.9966
#
# Epoch 00163: val_loss did not improve from 2950.84678
# Epoch 164/50000
# 4824/4824 [==============================] - 1s 106us/step - loss: 2202.7059 - mean_absolute_error: 2202.7059 - val_loss: 3412.6143 - val_mean_absolute_error: 3412.6143
#
# Epoch 00164: val_loss did not improve from 2950.84678
# Epoch 165/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2175.5702 - mean_absolute_error: 2175.5702 - val_loss: 3423.8666 - val_mean_absolute_error: 3423.8666
#
# Epoch 00165: val_loss did not improve from 2950.84678
# Epoch 166/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2194.9786 - mean_absolute_error: 2194.9786 - val_loss: 3450.3581 - val_mean_absolute_error: 3450.3581
#
# Epoch 00166: val_loss did not improve from 2950.84678
# Epoch 167/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2174.8520 - mean_absolute_error: 2174.8520 - val_loss: 3453.1092 - val_mean_absolute_error: 3453.1092
#
# Epoch 00167: val_loss did not improve from 2950.84678
# Epoch 168/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2169.0103 - mean_absolute_error: 2169.0103 - val_loss: 3423.0453 - val_mean_absolute_error: 3423.0453
#
# Epoch 00168: val_loss did not improve from 2950.84678
# Epoch 169/50000
# 4824/4824 [==============================] - 1s 110us/step - loss: 2169.8521 - mean_absolute_error: 2169.8521 - val_loss: 3443.6506 - val_mean_absolute_error: 3443.6506
#
# Epoch 00169: val_loss did not improve from 2950.84678
# Epoch 170/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2169.1805 - mean_absolute_error: 2169.1805 - val_loss: 3473.7634 - val_mean_absolute_error: 3473.7634
#
# Epoch 00170: val_loss did not improve from 2950.84678
# Epoch 171/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2147.7689 - mean_absolute_error: 2147.7689 - val_loss: 3482.1981 - val_mean_absolute_error: 3482.1981
#
# Epoch 00171: val_loss did not improve from 2950.84678
# Epoch 172/50000
# 4824/4824 [==============================] - 1s 114us/step - loss: 2147.0632 - mean_absolute_error: 2147.0632 - val_loss: 3455.3945 - val_mean_absolute_error: 3455.3945
#
# Epoch 00172: val_loss did not improve from 2950.84678
# Epoch 173/50000
# 4824/4824 [==============================] - 1s 116us/step - loss: 2154.7977 - mean_absolute_error: 2154.7977 - val_loss: 3450.8862 - val_mean_absolute_error: 3450.8862
#
# Epoch 00173: val_loss did not improve from 2950.84678
# Epoch 174/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2134.9680 - mean_absolute_error: 2134.9680 - val_loss: 3486.0838 - val_mean_absolute_error: 3486.0838
#
# Epoch 00174: val_loss did not improve from 2950.84678
# Epoch 175/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2125.7494 - mean_absolute_error: 2125.7494 - val_loss: 3481.4666 - val_mean_absolute_error: 3481.4666
#
# Epoch 00175: val_loss did not improve from 2950.84678
# Epoch 176/50000
# 4824/4824 [==============================] - 1s 116us/step - loss: 2114.0035 - mean_absolute_error: 2114.0035 - val_loss: 3478.2381 - val_mean_absolute_error: 3478.2381
#
# Epoch 00176: val_loss did not improve from 2950.84678
# Epoch 177/50000
# 4824/4824 [==============================] - 1s 116us/step - loss: 2122.8306 - mean_absolute_error: 2122.8306 - val_loss: 3459.1123 - val_mean_absolute_error: 3459.1123
#
# Epoch 00177: val_loss did not improve from 2950.84678
# Epoch 178/50000
# 4824/4824 [==============================] - 1s 113us/step - loss: 2110.2035 - mean_absolute_error: 2110.2035 - val_loss: 3507.5414 - val_mean_absolute_error: 3507.5414
#
# Epoch 00178: val_loss did not improve from 2950.84678
# Epoch 179/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2110.8797 - mean_absolute_error: 2110.8797 - val_loss: 3479.7346 - val_mean_absolute_error: 3479.7346
#
# Epoch 00179: val_loss did not improve from 2950.84678
# Epoch 180/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2114.9181 - mean_absolute_error: 2114.9181 - val_loss: 3506.0040 - val_mean_absolute_error: 3506.0040
#
# Epoch 00180: val_loss did not improve from 2950.84678
# Epoch 181/50000
# 4824/4824 [==============================] - 1s 113us/step - loss: 2126.4438 - mean_absolute_error: 2126.4438 - val_loss: 3520.7923 - val_mean_absolute_error: 3520.7923
#
# Epoch 00181: val_loss did not improve from 2950.84678
# Epoch 182/50000
# 4824/4824 [==============================] - 1s 116us/step - loss: 2119.4635 - mean_absolute_error: 2119.4635 - val_loss: 3489.6789 - val_mean_absolute_error: 3489.6789
#
# Epoch 00182: val_loss did not improve from 2950.84678
# Epoch 183/50000
# 4824/4824 [==============================] - 1s 113us/step - loss: 2088.1518 - mean_absolute_error: 2088.1518 - val_loss: 3564.7772 - val_mean_absolute_error: 3564.7772
#
# Epoch 00183: val_loss did not improve from 2950.84678
# Epoch 184/50000
# 4824/4824 [==============================] - 1s 120us/step - loss: 2108.8898 - mean_absolute_error: 2108.8898 - val_loss: 3469.2486 - val_mean_absolute_error: 3469.2486
#
# Epoch 00184: val_loss did not improve from 2950.84678
# Epoch 185/50000
# 4824/4824 [==============================] - 1s 113us/step - loss: 2092.1097 - mean_absolute_error: 2092.1097 - val_loss: 3520.6897 - val_mean_absolute_error: 3520.6897
#
# Epoch 00185: val_loss did not improve from 2950.84678
# Epoch 186/50000
# 4824/4824 [==============================] - 1s 116us/step - loss: 2067.3966 - mean_absolute_error: 2067.3966 - val_loss: 3537.1429 - val_mean_absolute_error: 3537.1429
#
# Epoch 00186: val_loss did not improve from 2950.84678
# Epoch 187/50000
# 4824/4824 [==============================] - 1s 114us/step - loss: 2082.0034 - mean_absolute_error: 2082.0034 - val_loss: 3496.8323 - val_mean_absolute_error: 3496.8323
#
# Epoch 00187: val_loss did not improve from 2950.84678
# Epoch 188/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2081.2117 - mean_absolute_error: 2081.2117 - val_loss: 3639.2874 - val_mean_absolute_error: 3639.2874
#
# Epoch 00188: val_loss did not improve from 2950.84678
# Epoch 189/50000
# 4824/4824 [==============================] - 1s 115us/step - loss: 2065.9031 - mean_absolute_error: 2065.9031 - val_loss: 3581.3233 - val_mean_absolute_error: 3581.3233
#
# Epoch 00189: val_loss did not improve from 2950.84678
# Epoch 190/50000
# 4824/4824 [==============================] - 1s 111us/step - loss: 2063.6367 - mean_absolute_error: 2063.6367 - val_loss: 3548.1116 - val_mean_absolute_error: 3548.1116
#
# Epoch 00190: val_loss did not improve from 2950.84678
# Epoch 191/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2039.6645 - mean_absolute_error: 2039.6645 - val_loss: 3556.9971 - val_mean_absolute_error: 3556.9971
#
# Epoch 00191: val_loss did not improve from 2950.84678
# Epoch 192/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2075.5192 - mean_absolute_error: 2075.5192 - val_loss: 3509.2811 - val_mean_absolute_error: 3509.2811
#
# Epoch 00192: val_loss did not improve from 2950.84678
# Epoch 193/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2076.7318 - mean_absolute_error: 2076.7318 - val_loss: 3535.7836 - val_mean_absolute_error: 3535.7836
#
# Epoch 00193: val_loss did not improve from 2950.84678
# Epoch 194/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2025.4934 - mean_absolute_error: 2025.4934 - val_loss: 3512.4556 - val_mean_absolute_error: 3512.4556
#
# Epoch 00194: val_loss did not improve from 2950.84678
# Epoch 195/50000
# 4824/4824 [==============================] - 1s 109us/step - loss: 2057.2604 - mean_absolute_error: 2057.2604 - val_loss: 3534.7791 - val_mean_absolute_error: 3534.7791
#
# Epoch 00195: val_loss did not improve from 2950.84678
# Epoch 196/50000
# 4824/4824 [==============================] - 1s 107us/step - loss: 2043.1793 - mean_absolute_error: 2043.1793 - val_loss: 3576.0735 - val_mean_absolute_error: 3576.0735
#
# Epoch 00196: val_loss did not improve from 2950.84678
# Epoch 197/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 2035.9342 - mean_absolute_error: 2035.9342 - val_loss: 3534.6633 - val_mean_absolute_error: 3534.6633
#
# Epoch 00197: val_loss did not improve from 2950.84678
# Epoch 198/50000
# ...
#
# Epoch 03657: val_loss did not improve from 2950.84678
# Epoch 3658/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 422.9600 - mean_absolute_error: 422.9600 - val_loss: 4528.0155 - val_mean_absolute_error: 4528.0155
#
# Epoch 03658: val_loss did not improve from 2950.84678
# Epoch 3659/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 415.8261 - mean_absolute_error: 415.8261 - val_loss: 4538.6101 - val_mean_absolute_error: 4538.6101
#
# Epoch 03659: val_loss did not improve from 2950.84678
# Epoch 3660/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 393.6696 - mean_absolute_error: 393.6696 - val_loss: 4522.9263 - val_mean_absolute_error: 4522.9263
#
# Epoch 03660: val_loss did not improve from 2950.84678
# Epoch 3661/50000
# 4824/4824 [==============================] - 0s 98us/step - loss: 412.5977 - mean_absolute_error: 412.5977 - val_loss: 4497.3256 - val_mean_absolute_error: 4497.3256
#
# Epoch 03661: val_loss did not improve from 2950.84678
# Epoch 3662/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 399.6548 - mean_absolute_error: 399.6548 - val_loss: 4515.5946 - val_mean_absolute_error: 4515.5946
#
# Epoch 03662: val_loss did not improve from 2950.84678
# Epoch 3663/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 419.0819 - mean_absolute_error: 419.0819 - val_loss: 4502.0322 - val_mean_absolute_error: 4502.0322
#
# Epoch 03663: val_loss did not improve from 2950.84678
# Epoch 3664/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 414.4630 - mean_absolute_error: 414.4630 - val_loss: 4514.9636 - val_mean_absolute_error: 4514.9636
#
# Epoch 03664: val_loss did not improve from 2950.84678
# Epoch 3665/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 420.7843 - mean_absolute_error: 420.7843 - val_loss: 4508.3262 - val_mean_absolute_error: 4508.3262
#
# Epoch 03665: val_loss did not improve from 2950.84678
# Epoch 3666/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 401.6908 - mean_absolute_error: 401.6908 - val_loss: 4515.5529 - val_mean_absolute_error: 4515.5529
#
# Epoch 03666: val_loss did not improve from 2950.84678
# Epoch 3667/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 380.0829 - mean_absolute_error: 380.0829 - val_loss: 4527.2114 - val_mean_absolute_error: 4527.2114
#
# Epoch 03667: val_loss did not improve from 2950.84678
# Epoch 3668/50000
# 4824/4824 [==============================] - 0s 102us/step - loss: 418.8669 - mean_absolute_error: 418.8669 - val_loss: 4515.5335 - val_mean_absolute_error: 4515.5335
#
# Epoch 03668: val_loss did not improve from 2950.84678
# Epoch 3669/50000
# 4824/4824 [==============================] - 0s 98us/step - loss: 404.7515 - mean_absolute_error: 404.7515 - val_loss: 4497.8811 - val_mean_absolute_error: 4497.8811
#
# Epoch 03669: val_loss did not improve from 2950.84678
# Epoch 3670/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 415.0665 - mean_absolute_error: 415.0665 - val_loss: 4485.0036 - val_mean_absolute_error: 4485.0036
#
# Epoch 03670: val_loss did not improve from 2950.84678
# Epoch 3671/50000
# 4824/4824 [==============================] - 0s 98us/step - loss: 385.4216 - mean_absolute_error: 385.4216 - val_loss: 4505.1870 - val_mean_absolute_error: 4505.1870
#
# Epoch 03671: val_loss did not improve from 2950.84678
# Epoch 3672/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 394.6426 - mean_absolute_error: 394.6426 - val_loss: 4512.3562 - val_mean_absolute_error: 4512.3562
#
# Epoch 03672: val_loss did not improve from 2950.84678
# Epoch 3673/50000
# 4824/4824 [==============================] - 0s 102us/step - loss: 388.8043 - mean_absolute_error: 388.8043 - val_loss: 4493.2040 - val_mean_absolute_error: 4493.2040
#
# Epoch 03673: val_loss did not improve from 2950.84678
# Epoch 3674/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 404.6341 - mean_absolute_error: 404.6341 - val_loss: 4526.7293 - val_mean_absolute_error: 4526.7293
#
# Epoch 03674: val_loss did not improve from 2950.84678
# Epoch 3675/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 416.7478 - mean_absolute_error: 416.7478 - val_loss: 4500.7339 - val_mean_absolute_error: 4500.7339
#
# Epoch 03675: val_loss did not improve from 2950.84678
# Epoch 3676/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 394.0047 - mean_absolute_error: 394.0047 - val_loss: 4516.8227 - val_mean_absolute_error: 4516.8227
#
# Epoch 03676: val_loss did not improve from 2950.84678
# Epoch 3677/50000
# 4824/4824 [==============================] - 0s 102us/step - loss: 403.4881 - mean_absolute_error: 403.4881 - val_loss: 4476.1777 - val_mean_absolute_error: 4476.1777
#
# Epoch 03677: val_loss did not improve from 2950.84678
# Epoch 3678/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 392.8422 - mean_absolute_error: 392.8422 - val_loss: 4506.0292 - val_mean_absolute_error: 4506.0292
#
# Epoch 03678: val_loss did not improve from 2950.84678
# Epoch 3679/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 418.6532 - mean_absolute_error: 418.6532 - val_loss: 4510.8662 - val_mean_absolute_error: 4510.8662
#
# Epoch 03679: val_loss did not improve from 2950.84678
# Epoch 3680/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 399.2514 - mean_absolute_error: 399.2514 - val_loss: 4499.7114 - val_mean_absolute_error: 4499.7114
#
# Epoch 03680: val_loss did not improve from 2950.84678
# Epoch 3681/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 398.6365 - mean_absolute_error: 398.6365 - val_loss: 4508.3815 - val_mean_absolute_error: 4508.3815
#
# Epoch 03681: val_loss did not improve from 2950.84678
# Epoch 3682/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 407.8830 - mean_absolute_error: 407.8830 - val_loss: 4538.2715 - val_mean_absolute_error: 4538.2715
#
# Epoch 03682: val_loss did not improve from 2950.84678
# Epoch 3683/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 397.3659 - mean_absolute_error: 397.3659 - val_loss: 4512.8971 - val_mean_absolute_error: 4512.8971
#
# Epoch 03683: val_loss did not improve from 2950.84678
# Epoch 3684/50000
# 4824/4824 [==============================] - 0s 98us/step - loss: 395.1646 - mean_absolute_error: 395.1646 - val_loss: 4509.4416 - val_mean_absolute_error: 4509.4416
#
# Epoch 03684: val_loss did not improve from 2950.84678
# Epoch 3685/50000
# 4824/4824 [==============================] - 0s 103us/step - loss: 405.7634 - mean_absolute_error: 405.7634 - val_loss: 4525.4636 - val_mean_absolute_error: 4525.4636
#
# Epoch 03685: val_loss did not improve from 2950.84678
# Epoch 3686/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 421.0014 - mean_absolute_error: 421.0014 - val_loss: 4523.3771 - val_mean_absolute_error: 4523.3771
#
# Epoch 03686: val_loss did not improve from 2950.84678
# Epoch 3687/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 410.8656 - mean_absolute_error: 410.8656 - val_loss: 4513.2279 - val_mean_absolute_error: 4513.2279
#
# Epoch 03687: val_loss did not improve from 2950.84678
# Epoch 3688/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 396.9676 - mean_absolute_error: 396.9676 - val_loss: 4505.1660 - val_mean_absolute_error: 4505.1660
#
# Epoch 03688: val_loss did not improve from 2950.84678
# Epoch 3689/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 407.1820 - mean_absolute_error: 407.1820 - val_loss: 4506.9443 - val_mean_absolute_error: 4506.9443
#
# Epoch 03689: val_loss did not improve from 2950.84678
# Epoch 3690/50000
# 4824/4824 [==============================] - 0s 98us/step - loss: 390.0344 - mean_absolute_error: 390.0344 - val_loss: 4508.7372 - val_mean_absolute_error: 4508.7372
#
# Epoch 03690: val_loss did not improve from 2950.84678
# Epoch 3691/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 408.0613 - mean_absolute_error: 408.0613 - val_loss: 4494.8412 - val_mean_absolute_error: 4494.8412
#
# Epoch 03691: val_loss did not improve from 2950.84678
# Epoch 3692/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 389.8727 - mean_absolute_error: 389.8727 - val_loss: 4497.3134 - val_mean_absolute_error: 4497.3134
#
# Epoch 03692: val_loss did not improve from 2950.84678
# Epoch 3693/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 394.1860 - mean_absolute_error: 394.1860 - val_loss: 4503.2950 - val_mean_absolute_error: 4503.2950
#
# Epoch 03693: val_loss did not improve from 2950.84678
# Epoch 3694/50000
# 4824/4824 [==============================] - 0s 102us/step - loss: 393.3278 - mean_absolute_error: 393.3278 - val_loss: 4493.4403 - val_mean_absolute_error: 4493.4403
#
# Epoch 03694: val_loss did not improve from 2950.84678
# Epoch 3695/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 405.3128 - mean_absolute_error: 405.3128 - val_loss: 4511.3180 - val_mean_absolute_error: 4511.3180
#
# Epoch 03695: val_loss did not improve from 2950.84678
# Epoch 3696/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 394.0665 - mean_absolute_error: 394.0665 - val_loss: 4504.0226 - val_mean_absolute_error: 4504.0226
#
# Epoch 03696: val_loss did not improve from 2950.84678
# Epoch 3697/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 415.9658 - mean_absolute_error: 415.9658 - val_loss: 4470.9414 - val_mean_absolute_error: 4470.9414
#
# Epoch 03697: val_loss did not improve from 2950.84678
# Epoch 3698/50000
# 4824/4824 [==============================] - 0s 102us/step - loss: 401.5535 - mean_absolute_error: 401.5535 - val_loss: 4529.5182 - val_mean_absolute_error: 4529.5182
#
# Epoch 03698: val_loss did not improve from 2950.84678
# Epoch 3699/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 399.8506 - mean_absolute_error: 399.8506 - val_loss: 4488.9440 - val_mean_absolute_error: 4488.9440
#
# Epoch 03699: val_loss did not improve from 2950.84678
# Epoch 3700/50000
# 4824/4824 [==============================] - 0s 103us/step - loss: 384.3675 - mean_absolute_error: 384.3675 - val_loss: 4516.2014 - val_mean_absolute_error: 4516.2014
#
# Epoch 03700: val_loss did not improve from 2950.84678
# Epoch 3701/50000
# 4824/4824 [==============================] - 0s 102us/step - loss: 379.4205 - mean_absolute_error: 379.4205 - val_loss: 4519.4500 - val_mean_absolute_error: 4519.4500
#
# Epoch 03701: val_loss did not improve from 2950.84678
# Epoch 3702/50000
# 4824/4824 [==============================] - 1s 105us/step - loss: 415.8095 - mean_absolute_error: 415.8095 - val_loss: 4492.6195 - val_mean_absolute_error: 4492.6195
#
# Epoch 03702: val_loss did not improve from 2950.84678
# Epoch 3703/50000
# 4824/4824 [==============================] - 0s 102us/step - loss: 405.4203 - mean_absolute_error: 405.4203 - val_loss: 4534.4670 - val_mean_absolute_error: 4534.4670
#
# Epoch 03703: val_loss did not improve from 2950.84678
# Epoch 3704/50000
# 4824/4824 [==============================] - 0s 103us/step - loss: 399.0950 - mean_absolute_error: 399.0950 - val_loss: 4509.7601 - val_mean_absolute_error: 4509.7601
#
# Epoch 03704: val_loss did not improve from 2950.84678
# Epoch 3705/50000
# 4824/4824 [==============================] - 0s 98us/step - loss: 396.8907 - mean_absolute_error: 396.8907 - val_loss: 4504.1649 - val_mean_absolute_error: 4504.1649
#
# Epoch 03705: val_loss did not improve from 2950.84678
# Epoch 3706/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 402.7871 - mean_absolute_error: 402.7871 - val_loss: 4519.4763 - val_mean_absolute_error: 4519.4763
#
# Epoch 03706: val_loss did not improve from 2950.84678
# Epoch 3707/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 411.9222 - mean_absolute_error: 411.9222 - val_loss: 4487.8946 - val_mean_absolute_error: 4487.8946
#
# Epoch 03707: val_loss did not improve from 2950.84678
# Epoch 3708/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 409.3587 - mean_absolute_error: 409.3587 - val_loss: 4514.0538 - val_mean_absolute_error: 4514.0538
#
# Epoch 03708: val_loss did not improve from 2950.84678
# Epoch 3709/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 411.1227 - mean_absolute_error: 411.1227 - val_loss: 4501.9492 - val_mean_absolute_error: 4501.9492
#
# Epoch 03709: val_loss did not improve from 2950.84678
# Epoch 3710/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 393.3246 - mean_absolute_error: 393.3246 - val_loss: 4528.8242 - val_mean_absolute_error: 4528.8242
#
# Epoch 03710: val_loss did not improve from 2950.84678
# Epoch 3711/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 407.3050 - mean_absolute_error: 407.3050 - val_loss: 4494.4511 - val_mean_absolute_error: 4494.4511
#
# Epoch 03711: val_loss did not improve from 2950.84678
# Epoch 3712/50000
# 4824/4824 [==============================] - 0s 99us/step - loss: 400.2966 - mean_absolute_error: 400.2966 - val_loss: 4495.4987 - val_mean_absolute_error: 4495.4987
#
# Epoch 03712: val_loss did not improve from 2950.84678
# Epoch 3713/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 411.6619 - mean_absolute_error: 411.6619 - val_loss: 4472.1416 - val_mean_absolute_error: 4472.1416
#
# Epoch 03713: val_loss did not improve from 2950.84678
# Epoch 3714/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 404.5967 - mean_absolute_error: 404.5967 - val_loss: 4491.2506 - val_mean_absolute_error: 4491.2506
#
# Epoch 03714: val_loss did not improve from 2950.84678
# Epoch 3715/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 411.2206 - mean_absolute_error: 411.2206 - val_loss: 4532.9351 - val_mean_absolute_error: 4532.9351
#
# Epoch 03715: val_loss did not improve from 2950.84678
# Epoch 3716/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 402.7024 - mean_absolute_error: 402.7024 - val_loss: 4514.8600 - val_mean_absolute_error: 4514.8600
#
# Epoch 03716: val_loss did not improve from 2950.84678
# Epoch 3717/50000
# 4824/4824 [==============================] - 0s 102us/step - loss: 400.9378 - mean_absolute_error: 400.9378 - val_loss: 4499.9172 - val_mean_absolute_error: 4499.9172
#
# Epoch 03717: val_loss did not improve from 2950.84678
# Epoch 3718/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 438.9408 - mean_absolute_error: 438.9408 - val_loss: 4503.4838 - val_mean_absolute_error: 4503.4838
#
# Epoch 03718: val_loss did not improve from 2950.84678
# Epoch 3719/50000
# 4824/4824 [==============================] - 0s 101us/step - loss: 393.1490 - mean_absolute_error: 393.1490 - val_loss: 4504.7651 - val_mean_absolute_error: 4504.7651
#
# Epoch 03719: val_loss did not improve from 2950.84678
# Epoch 3720/50000
# 4824/4824 [==============================] - 0s 98us/step - loss: 410.9463 - mean_absolute_error: 410.9463 - val_loss: 4510.2276 - val_mean_absolute_error: 4510.2276
#
# Epoch 03720: val_loss did not improve from 2950.84678
# Epoch 3721/50000
# 4824/4824 [==============================] - 1s 108us/step - loss: 393.1875 - mean_absolute_error: 393.1875 - val_loss: 4532.4673 - val_mean_absolute_error: 4532.4673
#
# Epoch 03721: val_loss did not improve from 2950.84678
# Epoch 3722/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 413.0249 - mean_absolute_error: 413.0249 - val_loss: 4507.0832 - val_mean_absolute_error: 4507.0832
#
# Epoch 03722: val_loss did not improve from 2950.84678
# Epoch 3723/50000
# 4824/4824 [==============================] - 0s 100us/step - loss: 411.7427 - mean_absolute_error: 411.7427 - val_loss: 4486.5887 - val_mean_absolute_error: 4486.5887
#
# Epoch 03723: val_loss did not improve from 2950.84678
# Epoch 3724/50000
#  608/4824 [==>...........................] - ETA: 0s - loss: 417.5934 - mean_absolute_error: 417.5934

# %%
# Load wights file of the best model :
wights_file = 'Weights-009--2961.04423.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %% [markdown]
# We see that the validation loss of the best model is 18738.19

# %% [markdown]
# ## Fourth : Test the model
# We will submit the predictions on the test data to Kaggle and see how good our model is.

# %%
def make_submission(prediction, sub_name):
  my_submission = pd.DataFrame({'Id':pd.read_csv('test.csv').Id,'Pontosx':prediction})
  my_submission.to_csv('{}.csv'.format(sub_name),index=False)
  print('A submission file has been made')

# %%
predictions = NN_model.predict(test)

# %%
make_submission(predictions[:,0],'submission(NN).csv')
# Out:
# A submission file has been made

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/800/1*mXbUrGB9yB9RrBscwugP9g.png)

# %% [markdown]
# Not bad at all, with some more preprocessing, and more training, we can do better.

# %% [markdown]
# ## Fifth: Try another ML algorithms :
# Now, let us try another ML algorithm to compare the results.
#
# We will use random forest regressor and XGBRegressor.

# %% [markdown]
# **Split training data to training and validation data**

# %%
train_X, val_X, train_y, val_y = train_test_split(train, target, test_size = 0.25, random_state = 14)

# %% [markdown]
# **We will try Random forest model first.**

# %%
model = RandomForestRegressor()
model.fit(train_X,train_y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# **Get the mean absolute error on the validation data **

# %%
predicted_prices = model.predict(val_X)
MAE = mean_absolute_error(val_y , predicted_prices)
print('Random forest validation MAE = ', MAE)
# Out:
# Random forest validation MAE =  3192.8912466843503

# %% [markdown]
# **Make a submission file and submit it to Kaggle to see the result.**

# %%
predicted_prices = model.predict(test)
make_submission(predicted_prices,'Submission(RF).csv')
# Out:
# A submission file has been made

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/800/1*wcJqKzBsbLARqMjwvv0Xjw.png)

# %% [markdown]
# **Now, let us try XGBoost model**

# %%
XGBModel = XGBRegressor()
XGBModel.fit(train_X,train_y , verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, importance_type='gain',
#        learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#        nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=1)

# %% [markdown]
# **Get the mean absolute error on the validation data**

# %%
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
# Out:
# XGBoost validation MAE =  3053.193298380318

# %% [markdown]
# **Make a submission file and submit it to Kaggle to see the result.**

# %%
XGBpredictions = XGBModel.predict(test)
make_submission(XGBpredictions,'Submission(XGB).csv')
# Out:
# A submission file has been made

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/800/1*PO0jxykz1hv-aSN5kkjItg.png)

# %% [markdown]
# Isn't that a surprise, I really did not think that neural networks will beat random forests and XGBoost algorithms, but let us try not to be too optimistic, remember that we did not configure any hyperparameters on random forest and XGBoost models, I believe if we did so, these two models would outscore neural networks.
