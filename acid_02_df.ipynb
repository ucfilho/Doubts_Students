# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Doubts_Students/blob/master/acid_02_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
a =['cinco_s','abs','cdf','kkk','cinco_s']
b =['1','1','1','1','1']
c =['cai','morri','dormi','voei','cai']
df = pd.DataFrame({'c':c,'b':b,'a':a})

# %%
df
# Out:
#        c  b        a
# 0    cai  1  cinco_s
# 1  morri  1      abs
# 2  dormi  1      cdf
# 3   voei  1      kkk
# 4    cai  1  cinco_s

# %%
idx = df[df['a']=='cinco_s'].index
print(idx)
# Out:
# Int64Index([0, 4], dtype='int64')

# %%
for k in idx:
  df.loc[k,'b']=1000

# %%
df
# Out:
#        c     b        a
# 0    cai  1000  cinco_s
# 1  morri     1      abs
# 2  dormi     1      cdf
# 3   voei     1      kkk
# 4    cai  1000  cinco_s

# %%
df2 = df[df.b != '1']
df2
# Out:
#      c     b        a
# 0  cai  1000  cinco_s
# 4  cai  1000  cinco_s

# %%
df3 = df[df.b == '1']
df3
# Out:
#        c  b    a
# 1  morri  1  abs
# 2  dormi  1  cdf
# 3   voei  1  kkk
